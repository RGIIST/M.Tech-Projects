# %%
from PIL import Image
from google.colab.files import upload
import requests
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'

import torch
from torch import nn
from torchvision.models import resnet50
import torchvision.transforms as T
torch.set_grad_enabled(False);

# %%
class DETRdemo(nn.Module):
    def __init__(self, num_classes, hidden_dim=256, nheads=8,
                 num_encoder_layers=6, num_decoder_layers=6):
        super().__init__()

        self.backbone = resnet50()
        del self.backbone.fc

        self.conv = nn.Conv2d(2048, hidden_dim, 1)

        self.transformer = nn.Transformer(
            hidden_dim, nheads, num_encoder_layers, num_decoder_layers)

        self.linear_class = nn.Linear(hidden_dim, num_classes + 1)
        self.linear_bbox = nn.Linear(hidden_dim, 4)

        self.query_pos = nn.Parameter(torch.rand(100, hidden_dim))

        self.row_embed = nn.Parameter(torch.rand(50, hidden_dim // 2))
        self.col_embed = nn.Parameter(torch.rand(50, hidden_dim // 2))

    def forward(self, inputs):
        x = self.backbone.conv1(inputs)
        x = self.backbone.bn1(x)
        x = self.backbone.relu(x)
        x = self.backbone.maxpool(x)

        x = self.backbone.layer1(x)
        x = self.backbone.layer2(x)
        x = self.backbone.layer3(x)
        x = self.backbone.layer4(x)

        h = self.conv(x)

        H, W = h.shape[-2:]
        pos = torch.cat([
            self.col_embed[:W].unsqueeze(0).repeat(H, 1, 1),
            self.row_embed[:H].unsqueeze(1).repeat(1, W, 1),
        ], dim=-1).flatten(0, 1).unsqueeze(1)
        
        
        h = self.transformer(pos + 0.1 * h.flatten(2).permute(2, 0, 1),self.query_pos.unsqueeze(1)).transpose(0, 1)
        print(h.shape)
        return {'pred_logits': self.linear_class(h), 'pred_boxes': self.linear_bbox(h).sigmoid()}

# %%
detr = DETRdemo(num_classes=91)
state_dict = torch.hub.load_state_dict_from_url(
    url='https://dl.fbaipublicfiles.com/detr/detr_demo-da2a99e9.pth',
    map_location='cpu', check_hash=True)
detr.load_state_dict(state_dict)
detr.eval();

# %%
CLASSES = [
    'N/A', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A',
    'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse',
    'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack',
    'umbrella', 'N/A', 'N/A', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis',
    'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove',
    'skateboard', 'surfboard', 'tennis racket', 'bottle', 'N/A', 'wine glass',
    'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich',
    'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake',
    'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table', 'N/A',
    'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard',
    'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A',
    'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier',
    'toothbrush'
]

COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]

transform = T.Compose([
    T.Resize(800),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

def rescale_bboxes(x,size):
  img_w,img_h=size
  x_c,y_c,w,h=x.unbind(1)
  b=[(x_c-0.5*w),(y_c-0.5*h),(x_c+0.5*w),(y_c+0.5*h)]
  return torch.stack(b,dim=1)*torch.tensor([img_w,img_h,img_w,img_h],dtype=torch.float32)

def detect(im, model, transform):
    img = transform(im).unsqueeze(0)
    # print("inputshape",img.shape)

    assert img.shape[-2] <= 1600 and img.shape[-1] <= 1600, 'demo model only supports images up to 1600 pixels on each side'

    outputs = model(img)
    # print(outputs)
    probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
    
    keep = probas.max(-1).values > 0.7
    bboxes_scaled = rescale_bboxes(outputs['pred_boxes'][0, keep], im.size)
    return probas[keep], bboxes_scaled

def plot_results(pil_img, prob, boxes):
    plt.figure(figsize=(16,10))
    plt.imshow(pil_img)
    ax = plt.gca()
    for p, (xmin, ymin, xmax, ymax), c in zip(prob, boxes.tolist(), COLORS * 100):
        ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                   fill=False, color=c, linewidth=3))
        cl = p.argmax()
        text = f'{CLASSES[cl]}: {p[cl]:0.2f}'
        ax.text(xmin, ymin, text, fontsize=15,
                bbox=dict(facecolor='yellow', alpha=0.5))
    plt.axis('off')
    plt.show()

# %%
url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
im = Image.open(requests.get(url, stream=True).raw)
scores, boxes = detect(im, detr, transform)
# Out:
# torch.Size([1, 100, 256])

# %%
plot_results(im, scores, boxes)

# %%
upload()
# Out:
#      <input type="file" id="files-f0bc6930-416d-4b8c-89d3-3a1efdc41913" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0bc6930-416d-4b8c-89d3-3a1efdc41913">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IMG_20210518_113058.jpg to IMG_20210518_113058 (1).jpg
# Saving rg bhai.jpg to rg bhai (1).jpg
# {'IMG_20210518_113058.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00CC"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x00\x05\x05\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x06\x07\x08\t\x00\x02\x03\x04\n\x01\x0b\xff\xc4\x00t\x10\x00\x01\x02\x04\x04\x03\x04\x06\x03\x08\t\x0b\n\x12\t\x05\x01\x02\x03\x00\x04\x05\x11\x06\x07\x12!\x081A\x13"Qa\t\x142q\x81\x91\x15#\xa1\n\x17BR\xb1\xc1\xd2\xd3\x16\x1a$Xbr\x96\xd1\xf0\x183CW\x82\x92\x93\xa2\xb2\xc2\xe1%&5UVcs\xb3\xc3\xf1\'678EHSTefuw\x83\x86\x94\x95\xa3\xb5\x19(4Ddtv\x84\x97FGx\x85\xc4\xff\xc4\x00\x1e\x01\x00\x01\x04\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x02\x03\x05\x06\x00\x01\x07\x08\t\n\xff\xc4\x00>\x11\x00\x01\x03\x03\x03\x02\x04\x04\x04\x05\x03\x03\x03\x05\x00\x00\x01\x00\x02\x03\x04\x05\x11\x06\x12!\x131\x07"AQ\x142a\x91\x08\x15q\x813B\xa1\xb1\xc1\x16#\xd1$4\xf0\tC\xf1\x175Rr\xe1\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xe6\x99\xafB\xael<@k:r\xe5`\xf5\xfa\x1ew\xf4aV\xc2\xbfs\xfb\x9d\xb8\xaaO\xd7%\xf3\xf7*e{\xc4\x16^\xa3O\xa9B\xc6\xdb\xd9>Q;\xb2\x8c\tr\x90\x14Oxt\x87g\x93sKT\xbb\x89\xd8\rdY"\xdc\xe2\xb7Gt\xaa\x99\xd8qX\xb9\x9fk\xees3\xe1\xd7\x03c\x88|\xa4\x04\xf5\xfa\x02\xa3\xfa\x11\xbc\xf7\xdc\xdf\xe7\xd3\x0c\x17\xcf\x119F\xe2BVt\xa6\x81Q\xbe\xc3\xf8\x91\xd6\x94\x9a\x94&\x02\x88$\xea\xd8\x084\xcc\xe9L\xb2\xc2\xc8\t:\xb6?\x1f\xf4F\xdfr\xabk\xb8\xc7\xd9\tY3\xe0\x8f!|\xf8s\x1f\xd1\xcd\x8e\xb2\xdeir\xb5\x0c\xc1\xc2\xb5\x15"na\x92\xa99\t\x84\x8dL\xba\xa6\xd5\xed\x0f\x14_\xe3\x07\x8c\x80\xf4Xc\xec\xff\x00\xcc\xcc1\x96T\x8c\xd8\xc0\xf8n\xa3\x8aYuRu*\xc52il\xa1H\x17\xd2\xa0\x81{\x9f(\x96\x0e5$\xe4\xe8x\xd7\x16\xe1\x86V\xa1S\xc2\xd8\xd2`N!b\xd7jm)\x98m@\xf5\x1fZ\xb1\xf0\x8c<\x0f\xe2#B\xe2C!\xaaN=\xd9\x05ciyy\x875[\xba\xb7\x12\x00\xf8\xef\x12T\xf5\x13I\x1eOuI~\xa0\xba6\xafnF\xdf\xd1G\xce(\xf4,f\xce\x13\xcc\xcc\xb8\xcbJ\x9eq\xe5\xf0\x9c\xccl\xc8^\x19\x94\xac"\x8f9\xea\xf2\x93\x81\xa7\x1cJ\xdd\x1anR\xae\xc4\x80\x06\xfb\xc1{\x1a\xfa\x1f33\x03\xe7\xb5\x0f"*\x99\xc3\x80\x17Y\xae\xca\xcf\x16k\xe8\xa5M\xa6U\x132\xc4\x0fWRJukY"\xdd#\xa6\x9e5\xd8\x98\xc39\xd7\x84\xeb\xf2r\xc1\xa1\x83\xb8\xa4\xa0TZPX\xb2\x1b{[\x1a\x8f\x913\x03\x7f(F}"\xd4\xd5\xe0\xee,2\xaf\x1dH\x9e\xcd\xa9,\xdb\x95~\xa4\xe2E\xb576\xd9M\xaf\xd4kR\x0f\xc2\x19\x9e\xb6X\xea\x18=\x0ftK\xaf\xb5\xfdp\xd0F\x0f\xd1@\x9e\x0c\xf42\xe6\x8e4\xa5\xcaU$\xf3\xa3.\xe5\x134\x92C\x13\x14\x89\xc2\xa4\xd9V\xde\xc9\x83\x8f\xff\x00A\x8ep\xeb\xd1\xf7\xee\xcb^\\\xfe\x86\x9d\xfd\x18\xe8g\x0caD\xe0\xccU\x89p\xafd\xfbMP\xf1D\xf4\xbb\r\xbe\x8d*\xd0\x95\x9d;|\xa1JSd<M\xc0\'`"\xb1w\xbf\xddi\xabKb\xc6\xcfN\x17@\xb7F\xca\x987?\xba\xe6\xaa_\xd0G\x9c\x93\x02\xe3<\xb2\xcd\x1eJ\xa2\xcf~\x8c\x0c\xc9z\x02s\xa6u\xe42\x8c\xf8\xca\xe4\x15~\x12\xa8\x93\xf6\xff\x00&:K\x97p\xb7\xa6\xc4\x8b\x81m\xe0\xedB\x9aJ_I\n\xeb\xb1&\x07\xa6\xd4W\x99{\xe3\xec\x8a\x92\x9a\x16\xb5s\x85%\xf78\x99\xf3:\x848\xdf\x119D\x90\xa4\xde\xca\xa0T\x7fF\x04\x93\xf769\xfc\xbe\\F\xe4\xf8\xf7\xe1\xfa\x8f\xe8GY\xd8I\xfe\xd6Q\x9b\xaa\xe7\xb2\xe7\xe7\x07\xa6N\xc3bv1!\x15\xf2\xe4]\xe6\xc6?D?J5\xc7\xf2>\xe6\xab?\xd7\xff\x00l~O\x0f\xfd_\xa9~\x84m#\xeeh8\x81_\xfd\xb2Y86\xbd\xbfc\xd5/\xd0\x8e\xc1\xd8\x07~\xe9\xb7\x8d\xa0U\n $\xe9#`\x06\xf0So5g\xd4-\x98\xe1\x01q\xe2>\xe6K\x882\x10\x7f\xaaW&\xae\xbeC\xf6;R\xfd\x08n<G\xfa\r\xf1o\x0b\xd8Ix\xa72x\xac\xc9\xa6]z]k\xa3\xd0d\xf0\xf5ESs\xaaH\xe4\xd8)\xd8\x7f\x08\xed\x1d\xdfI\xa1\x87\x1e\x91\x06a\x0c\xbc\xe3\xc8J\x96\xe9\xb ...
#  'rg bhai.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xfe\x00\x1fCompressed by jpeg-recompress\xff\xdb\x00\x84\x00\x04\x04\x04\x04\x04\x04\x04\x04\x04\x04\x06\x06\x05\x06\x06\x08\x07\x07\x07\x07\x08\x0c\t\t\t\t\t\x0c\x13\x0c\x0e\x0c\x0c\x0e\x0c\x13\x11\x14\x10\x0f\x10\x14\x11\x1e\x17\x15\x15\x17\x1e"\x1d\x1b\x1d"*%%*424DD\\\x01\x04\x04\x04\x04\x04\x04\x04\x04\x04\x04\x06\x06\x05\x06\x06\x08\x07\x07\x07\x07\x08\x0c\t\t\t\t\t\x0c\x13\x0c\x0e\x0c\x0c\x0e\x0c\x13\x11\x14\x10\x0f\x10\x14\x11\x1e\x17\x15\x15\x17\x1e"\x1d\x1b\x1d"*%%*424DD\\\xff\xc2\x00\x11\x08\x02\x08\x02\xb2\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x02\x02\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x05\x03\x06\x01\x02\x07\x00\x08\xff\xda\x00\x08\x01\x01\x00\x00\x00\x00\xf8k>\xdb;ZY\x8dU\xb8\x12\xa9\xf22]\xafO\xad\x92\xc5\xac\xb8)\xc4\xaaqf\x9bH\xc8fe\xd5\x9d \x15.\xf6\x85\xe3\xed%\x8b\xc3\x02_\x89XP1\x01\xb1\xf4~?\xb96B-\x88\x15f\xac\x85c?0\x101W\xb0j\xde\xb5H\xf6\xfe\xce\xfb\xcb\xefo\xb6\xf2I,\xb3{y\xcd\xd8\xcfL\xcc\xd1\xde=!HF\xd8Z\xf6BkT\xe7\x80`+M\xcb8\xd0O\r\xacR\xcf\xa8ao \x15\x9f\x98\xe3d\xfd\xcd\xc4:a\xe89\xe8\x0c\x0f\xd7Q\xd4F\xf8\xbb-o\x9c\xfb}\xb3\xb6\xfe\xdf;\xed\xbe\xdb\xcb6\xdb\x15\x89w \x9d\xa7\x9a{\x01\xab=\xb1\x9b\xbd\xfaG\xd0\xd6\xf0\x97E\x96\xeby\xc1\x8f\x14\x92\xc2&\xc5xh\xa0\x10P\xbet\xa1\x18[\xebc\xaa\xf9\xfas\x9akR1\x10\xeb#\xb0\xefj\xacs\xafg;\xed\xbf\xb3\xbev\'Y\x08\xd3r\x19\x02V\xe5\x9d\xb4X`\xee\xdbN\x12f2[>\x81\xce\x89\xd1\x07\xa8\x96kSX\xe0\x13i7\x1e\x19\xb4\xf6@\x10A9\x17\x0c\xc7\xacV+\xe8N!\xa2\xf2\xe9\x98\xe21V\x8fa2\xd3R\xe7Y\xf6\xf8#\xa1\xb2\xa6\x90\x9e\x0fbM\xf6\x92B$3\xdb?\xe8\xa8(\xc7\xb9\xba\xd7\xd4\xcffP\xe3\xe8\xdc\xec\xad:\\\xe9`\xb3\xb2\x9c0w\x84\xc8\x07\'\xde\xd1|b\x85X\xf9\x80\x08\xac\rn\xd6\xd2\xe3\xa8\xf2Em\xb1\xa0\xaa\xe1v\xee\xc9O\xe7[\x9dbv\xdf\xa5\x1at\x91\xad\xe7\x14\x17\xceT\xab\x15\x80%\xfa9."\xd7\xd9<{\x85\xca\xefX\x03\xe8\xdd$\x81J\xa8uks\xdd\xba\xe0s\xac\xf9\xcc{\xc7\x98\x97\x88(\xbf8Q\x84)\xad\x83\xac\xcb*\x1ecO7m\x16%\x99\xdd\x95\xf59\x07Pk\x04n\x0c\x86\xc0\xc5\x89;\xc6YRB\xb7~A\xca\xe402\x8c\x11\x9b\xa9\xe0\x8c{\x87\xa7\xfa\x14]\xa4H\xbfx\x98\xdb\xbc\xda4dhF\xe7\x0e7\xb5\xdc\x08\xe2\x1b\x9a|\xf0\xa7Gm\xba\xb3c\x17s\xeec\xb90\xa6];k#\xca\xb3\xd3\xf4\xd5\x9c\xe1-\xbd\\\xcd\x9ex\x0c:]\xf2\x08|\xbe\x80\x93\x02\x9f\x19\x17\x88\xabv+J\xb7:v\xd0\r\x13H\xb6\x076}\x9e\x9b[\x15U\xbeSr\xbfXH\x15t\\\xf1\xdf\xcd\x15\xc1.eZ\xed\xe9\x1d\xa5\xe5\xf4\xc2a\x00MK\xbc\x10\xac\x9249\x88\xcb\xca\xea\xef\x89\x96i2q9L\x9a\xc7\xe1j\xfc\x92\xa5\xa6\xc7=\xb2Unv\xba\xf5\x928\xaa2\xda\xac1?R}\x90f7ng\x1a\xc9\xed5\xb7\xf6\x8a\xad>\xc4\x91\r\xb7\x9c\x93^\xe7\xab\xba\xda\xf8\x1d.v\x955,\xf5t\xe0\x87:\xe8\xc1p\xa5\xc8\xf7\xc3&\xbd\xf4\x86\x04\x91,\xb2\x16_\xab\\\xea\xedh\xae\x0bl\xaapd\xbe&\xdc5\xf1\x88\x82Th\xde\x10\xe6\xbd\xaa\xf6?\xaca\x13s\xa9n\x83 \xeb\xee\xb7\xc9\x9c\xd4\xf0\xe92-\x17\xf1\x8d:\xa8\x1b8&\x12k#\xd2\xca\xa2\x07\x0b\x1b=\x89\x02Y\xd8\xbd\x1b\x15\xae\xf2\xec\xf3\x08#i\x8b\x94\x88xS>\x9d\x9aM\x99\xddK\xe7\x91\xa6\x82\xc3t\xaf]8\xd2)\xa5\x1e<Y\xfe\xa6\xdf[Hr\xdak)g\xf4\x0b\x99\xf4Z\rY\xb2\xfb\x12\x05\xfb\xa0\xe2\xd5\x9e\xca*K!^b\xa0$\x95\xcaN\xc1\x99g\xb0\xa3\xac\xb2\xb3\xec&\xa3w\xc6\x05\x934\x9b\x12n\xf3\x11\xca\xf8\xf7\xd0\xfb\xd6sp\xcf\xcf\x15\xa8\xe4\xd1\x99\n\xe9\xed\x9e\xb7\x90\n\xa6\xbfY\xd9\xa3\xe8\xd3c\xdaD<\xa1\x88y\x03\xa4\xcc\x85\x82\x0f*\xb5s\x1e\x10tL]t{\x9cJ\xa9\xab\xb9\xfdgh\xbdq\xb1\xa0\xaaZX\x8b*kOi0&\x0c\xe7\xdc\x89\xe4\x98\x8ag\xca_J\xb7R\xba\xf4\x9b\x92.\x16?G\xea\x88\xb76\xae\xcc\x01\r#\xbf\xf6\x11\xbaf\x85\x8a9aN.5\x97+\x82\xd8\x81`\x80J\xc7\xcd\xd5\xc0\xf6\xb0Z\xfa\x8bU\xa2(\xe5\xdc\xf21\xf1k\xbb\xd6\xc6u\xe5\xcbk\xfdj\xd9\xcfv\xe9\x1d\t\x86a\xf6N1g\xc9}\x99\x8a\x93\xee\xd5\xba\xc0x\xdd^\xc7\xf2\xa5\x17cn\xcd\x96S*_@\xf4`\xfa\xea\x9c\x8cy\x9e\x11\x13\xb8t1E3B\xda\xed\\\xb0\xa4\xe7<\xee\x91^qb\xbat]\x83\x01o/\xa0\xa9\xd5\xdfK\xad\xa8u\x94\xe8\x87\xea\x95\x9a\x9c\xfdc\xb4>\x90T\x9c\xc5gj\xb1\xfc\xc5iz\x96\xdc\xf5`\x90c>\x1c^<\x13\xd ...

# %%
im1=Image.open('IMG_20210518_113058.jpg')
scores,boxes=detect(im1,detr,transform)
plot_results(im1,scores,boxes)

# %%
im2=Image.open('rg bhai.jpg')
scores,boxes=detect(im2,detr,transform)
plot_results(im2,scores,boxes)
